# %% [markdown]
# # Location recommendation for new Restaurant in Hyderabad, India
#
#
# ### by Venu Siva Vardhan Sivuni

# %% [markdown]
# ## Client Name :
# ## **TeamV5** , Hyderabad India

# %% [markdown]
# ## Introduction
#
# I was approached by a startup team, named 'TeamV5' restaurant to help in finding best place for those to start a new restaurant in Hyderabad, India.  Hyderabad is the capital city of Telangana State of India, has an estimated population of around 8 million. Hyderabad is a hub of trade and commerce and an international center for information technology (IT).
#
# Some of team members are based out of hyderabad but they don't have prior experience on restaurant business. Other team members having experience in restaurant business but relatively new to Hyderabad, India and customer tastes.
#
# So the team decided to take help of data and approached me (data scientist).

# %% [markdown]
# ## Business Probelem (requirements):
#
# Upon initial agreement to assist TeamV5, following requirements/business needs are identified in series of dicussions:
#
# 1. Type of Restaurant - Italian or Muti-cuisine
#
# 2. What are the key decision making factors that 'TeamV5' decide restaurant's location, such as shopping centers, gaming zones, Night life etc.
#
# 3. Is team want's rent the place or they would like to buy/start in their own location
#
# 4. Are there any existing Italian resturants in same/nearby location where TeamV5 considering to setup their restaurant? and ratings of such existing restaurants?
#
# 5. Is it risky to open new restaurant in same location or it helps to grab customers more quickly?
#
# 6. Are there any locations shortlisted by the team yet or they are open anywhere in Hyderabad?
#
#
# Out of scope: Investment/budget limitations, decisions on staff recruitmentment/chefs, offers etc are out of scope from Data Scientist.

# %% [markdown]
# ## Discussion:
#
# In a series of further discussions with TeamV5, it is mutually agreed/concluded as below (response/answers to problems identified at requirements section):
#
# 1. TeamV5 confirmed they are going to setup "ITALIAN" Restaurant. TeamV5 clarified, they would like to go for rent to minimize investment cost being a startup company. (Though have long term plans to buy property of their own)
#
# 2. TeamV5 considering locations such as Jubilee Hills/Banjara Hills where existing Italian restaurants running since many years.
#
# 3. I have assured to provide list of Italian restuarnats in and around same location of Hyderabad city (with help of data from foursquare.com).
#
# 4. TeamV5 considering locations close by to existing other Italian restaurants to grab like minded customers and confident to hold them with their quality of food and service. I have assured to provide ratings of existing Italian restaurants, provided available in foursquare website/database.
#
# 5. TeamV5 considered to open restaurant in close by location of existing Italian restaurant, as this is less risky than opening restaurant in all together new location and experiment. (As this is their business decision, haven't interfered and respected their decision)
#
# 6. I have offered to provide restaurant's opening and closing timings. This information provide them to decide opening/closing timings of proposed new restaurant. TeamV5 appreciated this valuable input and assured to consider to have more flexible timings to grab more customers/business.

# %% [markdown]
# ### Import necessary Libraries

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Defining Foursquare Credentials and Version

# %%
CLIENT_ID = '4KH2HQN3ZHF2FIZRZIYWCAPZUXR2GHVAI1A1XJQ3BK5JJFOT' # your Foursquare ID
CLIENT_SECRET = '4MEURFDH4LEIT2HL351U0PE22G2BAU5YHB1OOPZXGP0JTUR3' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 4KH2HQN3ZHF2FIZRZIYWCAPZUXR2GHVAI1A1XJQ3BK5JJFOT
# CLIENT_SECRET:4MEURFDH4LEIT2HL351U0PE22G2BAU5YHB1OOPZXGP0JTUR3

# %% [markdown]
# #### Converting the Little Italy, jubilee hills address to its latitude and longitude coordinates.

# %%
address = 'F550, Aryon (Apollo Rd no 92, Jubilee Hill)'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = 17.327042 ## location.latitude
longitude = 78.660221 ## location.longitude
print(latitude, longitude)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# 17.327042 78.660221

# %% [markdown]
# ### Search for a specific venue category
#
# #### Define a query to search for restaurants that offer Italian food and nearby Little Italy

# %%
search_query = 'Italian'
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4KH2HQN3ZHF2FIZRZIYWCAPZUXR2GHVAI1A1XJQ3BK5JJFOT&client_secret=4MEURFDH4LEIT2HL351U0PE22G2BAU5YHB1OOPZXGP0JTUR3&ll=17.327042,78.660221&v=20180604&query=Italian&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5be8e3d74434b963199fc910'},
#  'response': {'venues': [{'id': '5362542b11d28af3e7673551',
#     'name': 'Italian Pizza',
#     'location': {'lat': 17.45089829798461,
#      'lng': 78.51020621617091,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.45089829798461,
#        'lng': 78.51020621617091}],
#      'distance': 21072,
#      'cc': 'IN',
#      'city': 'Secunderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Secunderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1541989335',
#     'hasPerk': False},
#    {'id': '5533ddc1498e7dc6438723fd',
#     'name': 'Italian Pizza',
# ...

# %% [markdown]
# #### Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...    False
#
#                          id        location.address location.cc location.city  \
# 0  5362542b11d28af3e7673551                     NaN          IN  Secunderabad
# 1  5533ddc1498e7dc6438723fd  Ratnadeep, Hitech City          IN     Hyderabad
# 2  5533de65498e4134d708dbba   Ratnadeep Hitech City          IN     Hyderabad
# 3  54057e4c498ed1980135ab81                Rd No:12          IN     Hyderabad
# 4  596a6b71ee71207bf68b9672               Car Khana          IN     Hyderabad
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN              21072
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                              name          categories  \
# 0                                   Italian Pizza         Pizza Place
# 1                                   Italian Pizza         Pizza Place
# 2                                   Italian Pizza         Pizza Place
# 3                              Mozzarella Italian  Italian Restaurant
# 4                    Amore Gourmet Italian Gelato      Ice Cream Shop
# 5             Minus 4 - Italian concept Icecreams        Dessert Shop
# 6                                 Gelato Italiano        Dessert Shop
# 7   dinshaw's Italian Pizza And Ice Cream Parlour         Pizza Place
# 8                                 Gelato Italiano      Ice Cream Shop
# 9                      Gelato Italiano @Sameplace      Ice Cream Shop
# 10                                Gelato Italiano      Ice Cream Shop
# 11                                Gelato Italiano      Ice Cream Shop
#
# ...

# %%
dataframe_filtered.name
# Out:
# 0                                     Italian Pizza
# 1                                     Italian Pizza
# 2                                     Italian Pizza
# 3                                Mozzarella Italian
# 4                      Amore Gourmet Italian Gelato
# 5               Minus 4 - Italian concept Icecreams
# 6                                   Gelato Italiano
# 7     dinshaw's Italian Pizza And Ice Cream Parlour
# 8                                   Gelato Italiano
# 9                        Gelato Italiano @Sameplace
# 10                                  Gelato Italiano
# 11                                  Gelato Italiano
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=11) # generate map of Hyderabad with Italian resturants

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Conclusion:
#
#  TeamV5 decided to setup new restaurant in Jubilee Hills/Banjara Hills depending on the rental space they are going to get, as other Italian restaurants are mostly close by to these locations and also have existing customer base in these locations. Opening restaurants in all together new areas may be risky per TeamV5.
#
#
# Note: Please note this is an attempt to demonistrete for assignment and in real life, it requires in depth analysis and gathering data for other than foursquare website is required. (such as rental values).

# %% [markdown]
# ### Thank you
